# %%
import random

# Function to create a deck of cards for a specific suit
def create_deck(suit):
    ranks = ['2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King', 'Ace']
    deck = [(rank, suit) for rank in ranks]
    return deck

# Function to initialize player decks
def initialize_players():
    suits = ['Hearts', 'Clubs', 'Spades']
    user_suit = random.choice(suits)
    suits.remove(user_suit)
    computer_suit = suits[0]
    user_deck = create_deck(user_suit)
    computer_deck = create_deck(computer_suit)
    return user_deck, computer_deck

# Function to create a deck of diamond cards
def create_diamond_deck():
    diamond_ranks = ['2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King', 'Ace']
    diamond_deck = [(rank, 'Diamonds') for rank in diamond_ranks]
    random.shuffle(diamond_deck)
    return diamond_deck

# Function to calculate bid value based on card rank
def calculate_bid_value(card):
    rank = card[0]
    if rank.isdigit():
        return int(rank)
    elif rank == 'Ace':
        return 14
    elif rank == 'King':
        return 13
    elif rank == 'Queen':
        return 12
    elif rank == 'Jack':
        return 11

# Function to display the card
def display_card(card):
    print(f"The diamond card is: {card[0]} of {card[1]}")

# Function for user bidding
def user_bid(user_deck):
    print("Your cards:")
    for card in user_deck:
        print(f"{card[0]} of {card[1]}")
    while True:
        bid_card_rank = input("Choose a card rank to bid (e.g., 2, 3, Jack): ").strip().title()
        bid_card = (bid_card_rank, 'Hearts')  # Assume user's suit is always hearts
        if bid_card not in user_deck:
            print("Invalid card rank. Please choose from your cards.")
        else:
            user_deck.remove(bid_card)
            return bid_card

# Function for computer bidding
def computer_bid(computer_deck):
    bid_card = random.choice(computer_deck)
    computer_deck.remove(bid_card)
    return bid_card

# Function to determine the winner of the round
def determine_winner(user_bid_value, computer_bid_value, diamond_value):
    if user_bid_value > computer_bid_value:
        print("You win the bid!")
        return 'user'
    elif user_bid_value < computer_bid_value:
        print("Computer wins the bid!")
        return 'computer'
    else:
        print("It's a tie! Both players share the diamond value.")
        return 'tie'

# Function to play the game
def play_game():
    user_deck, computer_deck = initialize_players()
    diamond_deck = create_diamond_deck()
    user_points = 0
    computer_points = 0

    while diamond_deck:
        diamond_card = diamond_deck.pop()
        display_card(diamond_card)

        user_bid_card = user_bid(user_deck)
        user_bid_value = calculate_bid_value(user_bid_card)

        computer_bid_card = computer_bid(computer_deck)
        computer_bid_value = calculate_bid_value(computer_bid_card)

        print(f"User bid: {user_bid_card[0]} of {user_bid_card[1]} (Value: {user_bid_value})")
        print(f"Computer bid: {computer_bid_card[0]} of {computer_bid_card[1]} (Value: {computer_bid_value})")

        winner = determine_winner(user_bid_value, computer_bid_value, calculate_bid_value(diamond_card))

        if winner == 'user':
            user_points += calculate_bid_value(diamond_card)
            print(f"You gain {calculate_bid_value(diamond_card)} points!")
        elif winner == 'computer':
            computer_points += calculate_bid_value(diamond_card)
            print(f"Computer gains {calculate_bid_value(diamond_card)} points!")
        else:
            points = calculate_bid_value(diamond_card) / 2
            user_points += points
            computer_points += points
            print(f"Both players gain {points} points!")

    print("\nGame over!")
    print("Total points:")
    print(f"User: {user_points}")
    print(f"Computer: {computer_points}")

    if user_points > computer_points:
        print("Congratulations! You win!")
    elif user_points < computer_points:
        print("Computer wins!")
    else:
        print("It's a tie!")

# Main function to start the game
def main():
    print("Welcome to the Diamond Game!")
    play_game()

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Diamond Game!
# The diamond card is: 4 of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 4 of Hearts
# 5 of Hearts
# 6 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): 4
# User bid: 4 of Hearts (Value: 4)
# Computer bid: Jack of Clubs (Value: 11)
# Computer wins the bid!
# Computer gains 4 points!
# The diamond card is: Ace of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 5 of Hearts
# 6 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): Ace
# User bid: Ace of Hearts (Value: 14)
# Computer bid: King of Clubs (Value: 13)
# You win the bid!
# You gain 14 points!
# The diamond card is: 6 of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 5 of Hearts
# 6 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): 6
# User bid: 6 of Hearts (Value: 6)
# Computer bid: 8 of Clubs (Value: 8)
# Computer wins the bid!
# Computer gains 6 points!
# The diamond card is: King of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 5 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): King
# User bid: King of Hearts (Value: 13)
# Computer bid: Ace of Clubs (Value: 14)
# Computer wins the bid!
# Computer gains 13 points!
# The diamond card is: Queen of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 5 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Jack of Hearts
# Queen of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): Queen
# User bid: Queen of Hearts (Value: 12)
# Computer bid: 7 of Clubs (Value: 7)
# You win the bid!
# You gain 12 points!
# The diamond card is: Jack of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 5 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Jack of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): Jack
# User bid: Jack of Hearts (Value: 11)
# Computer bid: 4 of Clubs (Value: 4)
# You win the bid!
# You gain 11 points!
# The diamond card is: 10 of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 5 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): 10
# User bid: 10 of Hearts (Value: 10)
# Computer bid: 10 of Clubs (Value: 10)
# It's a tie! Both players share the diamond value.
# Both players gain 5.0 points!
# The diamond card is: 9 of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 5 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): 9
# User bid: 9 of Hearts (Value: 9)
# Computer bid: 5 of Clubs (Value: 5)
# You win the bid!
# You gain 9 points!
# The diamond card is: 5 of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 5 of Hearts
# 7 of Hearts
# 8 of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): 5
# User bid: 5 of Hearts (Value: 5)
# Computer bid: 6 of Clubs (Value: 6)
# Computer wins the bid!
# Computer gains 5 points!
# The diamond card is: 3 of Diamonds
# Your cards:
# 2 of Hearts
# 3 of Hearts
# 7 of Hearts
# 8 of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): 3
# User bid: 3 of Hearts (Value: 3)
# Computer bid: 3 of Clubs (Value: 3)
# It's a tie! Both players share the diamond value.
# Both players gain 1.5 points!
# The diamond card is: 7 of Diamonds
# Your cards:
# 2 of Hearts
# 7 of Hearts
# 8 of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): 7
# User bid: 7 of Hearts (Value: 7)
# Computer bid: 2 of Clubs (Value: 2)
# You win the bid!
# You gain 7 points!
# The diamond card is: 8 of Diamonds
# Your cards:
# 2 of Hearts
# 8 of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): 8
# User bid: 8 of Hearts (Value: 8)
# Computer bid: 9 of Clubs (Value: 9)
# Computer wins the bid!
# Computer gains 8 points!
# The diamond card is: 2 of Diamonds
# Your cards:
# 2 of Hearts
# Choose a card rank to bid (e.g., 2, 3, Jack): 2
# User bid: 2 of Hearts (Value: 2)
# Computer bid: Queen of Clubs (Value: 12)
# Computer wins the bid!
# Computer gains 2 points!
#
# Game over!
# Total points:
# User: 59.5
# Computer: 44.5
# Congratulations! You win!
